# %%
# Importar librerias
import pandas as pd
import numpy as np

# Visualización de missing values
import missingno as msno
# %matplotlib inline

from jupyterthemes import jtplot
jtplot.style(theme='monokai', context='notebook', ticks=True, grid=False)

#Configuración de  pandas 
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
df = pd.read_excel('sempli.xlsx', sheet_name=0, header=1).replace('SIN INFO', np.nan)

# %%
df.head(30)
# Out:
#     ID Cliente  Monto Acumulado Uso de los recursos              Plazo     Sector  Ingresos            Ubicación  Estrato Mínimo     Procesos judiciales     Alertas  Subpoblación  Score Bureau Empresa  Probabilidad de No Pago  Huellas de Consulta  Tiempo en el negocio Website empresa Instagram empresa LinkedIn empresa     LinkedIn empresarios  Edad empresarios Canal de captura                  Activador  Número de accionistas     Impacto Acceso previso a la banca  # Empleados     Mujeres empresarias  Mujeres en cargos directivos  Saldo  29/02/20  Saldo 31/05/20  Saldo 31/08/20  Refinanciado  Reestructurado  Castigado  Sempli Score         Garantía  12 Meses  31/03/2020   12 Meses  31/03/2020 RANGO  6 Meses     31/03/2020 6 Meses     31/03/2020 RANGO  6 Meses     31/08/2020 6 Meses     31/08/2020 RANGO               Cliente Sempli  Créditos cancelados 29/02/20  Créditos cancelados 31/08/20       COVID
# ...

# %%
df.shape
# Out:
# (638, 46)

# %%
# Tipo de por cada columna
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 638 entries, 0 to 637
# Data columns (total 46 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ID Cliente                    636 non-null    float64
#  1   Monto Acumulado               638 non-null    int64
#  2   Uso de los recursos           638 non-null    object
#  3   Plazo                         638 non-null    object
#  4   Sector                        638 non-null    object
#  5   Ingresos                      638 non-null    object
#  6   Ubicación                     638 non-null    object
#  7   Estrato Mínimo                638 non-null    int64
#  8   Procesos judiciales           638 non-null    object
#  9   Alertas                       638 non-null    object
#  10  Subpoblación                  634 non-null    float64
#  11  Score Bureau Empresa          634 non-null    float64
# ...

# %%
# Comprobar valores nulos por tablas
df.isnull().sum()
# Out:
# ID Cliente                        2
# Monto Acumulado                   0
# Uso de los recursos               0
# Plazo                             0
# Sector                            0
# Ingresos                          0
# Ubicación                         0
# Estrato Mínimo                    0
# Procesos judiciales               0
# Alertas                           0
# Subpoblación                      4
# Score Bureau Empresa              4
# Probabilidad de No Pago           4
# Huellas de Consulta               2
# Tiempo en el negocio              0
# Website empresa                   0
# Instagram empresa                 0
# LinkedIn empresa                  0
# LinkedIn empresarios              0
# Edad empresarios                  0
# Canal de captura                  0
# Activador                         2
# Número de accionistas             1
# Impacto                           0
# Acceso previso a la banca         0
# # Empleados                       0
# ...

# %%
# Visualizar valores nulos
msno.matrix(df)

# %%
# Visualizar la matriz de correlacion de missing values
msno.heatmap(df)

# %% [markdown]
# Se observaa...

# %%
df.groupby('Garantía').count()
# Out:
#                  ID Cliente  Monto Acumulado  Uso de los recursos  Plazo  Sector  Ingresos  Ubicación  Estrato Mínimo  Procesos judiciales  Alertas  Subpoblación  Score Bureau Empresa  Probabilidad de No Pago  Huellas de Consulta  Tiempo en el negocio  Website empresa  Instagram empresa  LinkedIn empresa  LinkedIn empresarios  Edad empresarios  Canal de captura  Activador  Número de accionistas  Impacto  Acceso previso a la banca  # Empleados  Mujeres empresarias  Mujeres en cargos directivos  Saldo  29/02/20  Saldo 31/05/20  Saldo 31/08/20  Refinanciado  Reestructurado  Castigado  Sempli Score  12 Meses  31/03/2020  12 Meses  31/03/2020 RANGO  6 Meses     31/03/2020  6 Meses     31/03/2020 RANGO  6 Meses     31/08/2020  6 Meses     31/08/2020 RANGO  Cliente Sempli  Créditos cancelados 29/02/20  Créditos cancelados 31/08/20  COVID
# Garantía
# ...

# %% [markdown]
# ### Estadistica

# %%
df.describe()
# Out:
#          ID Cliente  Monto Acumulado  Estrato Mínimo  Subpoblación  Score Bureau Empresa  Probabilidad de No Pago  Huellas de Consulta  Tiempo en el negocio  Edad empresarios  Número de accionistas  # Empleados  Mujeres en cargos directivos  Saldo  29/02/20  Saldo 31/05/20  Saldo 31/08/20  Refinanciado  Reestructurado   Castigado  Sempli Score  12 Meses  31/03/2020  6 Meses     31/03/2020  6 Meses     31/08/2020  Créditos cancelados 29/02/20  Créditos cancelados 31/08/20
# count    636.000000     6.380000e+02      638.000000    634.000000            634.000000               634.000000           636.000000            638.000000        638.000000             637.000000   638.000000                    638.000000     6.380000e+02    6.380000e+02    6.380000e+02    638.000000      638.000000  638.000000    638.000000            256.000000              473.000000              638.000000                    638.000000                    638.000000
# ...

# %% [markdown]
# #### Por hacer Andrés
# Correlaciones
# + pearson / spearman
# + distribucciones --> Comprobar si son gaussianas (graficarlas)
# + Diagrama de cajas y bigotes
# + Resumen estadistico por columnas --> df.describe()
# NOTA: Mirar el video de youtube
#
# -------->  Cambiar nombres a (SI/NO) :
#
# + procesos judiciales
# + alertas
# + impacto
# + la sección profiling
# + impacto
# + acceso previa la banca
# + mujeres empresarias
# + garantia
# + covid
#
# #### Por hacer Carlos
# one-hot encoding para:
# + sector
# + ingresos
# + plazo
# + ubicación
# + procesos judiciales
# + alertas
# + website
# + instagram
# + linkedin
# + canal de apertura
# + activador
# + impacto
# + impacto
# + acceso previa la banca
# + mujeres empresarias
# + garantia
# + cliente sempli
# + covid
